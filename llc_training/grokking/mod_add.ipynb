# %% [markdown]
# # Grokking
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/timaeus-research/devinterp/blob/main/examples/grokking.ipynb)

# %% [markdown]
# This notebook aims to investigate how LLC estimation could be used as a training metric using a modular addition task.
#
# This is based off the Timaeus grokking notebook found here: https://github.com/timaeus-research/devinterp/blob/main/examples/grokking.ipynb

# %%
# %pip install devinterp nbformat
# Out:
# Requirement already satisfied: devinterp in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: nbformat in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (5.10.4)
# Requirement already satisfied: einops>=0.6.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from devinterp) (0.8.1)
# Requirement already satisfied: matplotlib>=3.7.5 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from devinterp) (3.10.6)
# Requirement already satisfied: numpy>=1.23.5 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from devinterp) (2.2.6)
# Requirement already satisfied: pandas>=1.5.3 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from devinterp) (2.3.3)
# Requirement already satisfied: torch>=2.0.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from devinterp) (2.9.0)
# Requirement already satisfied: tqdm>=4.65.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from devinterp) (4.67.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from devinterp) (3.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat) (0.29.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (25.0)
# Requirement already satisfied: pillow>=8 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from matplotlib>=3.7.5->devinterp) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from pandas>=1.5.3->devinterp) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from pandas>=1.5.3->devinterp) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->devinterp) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Requirement already satisfied: filelock in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (3.4.2)
# Requirement already satisfied: jinja2 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from torch>=2.0.1->devinterp) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.1->devinterp) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages (from jinja2->torch>=2.0.1->devinterp) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
from copy import deepcopy
from dataclasses import dataclass

import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from tqdm import tqdm
from torchinfo import summary

from devinterp.optim.sgld import SGLD
from devinterp.slt.sampler import estimate_learning_coeff_with_summary
from devinterp.utils import evaluate_ce

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
@dataclass
class ExperimentParams:
    p: int = 53
    n_batches: int = 50000
    n_save_model_checkpoints: int = 100
    print_times: int = 100
    lr: float = 0.005
    batch_size: int = 128
    hidden_size: int = 48
    embed_dim: int = 12
    train_frac: float = 0.4
    # the shown grokking / llc curve behavior is robust to change of seed from my experiments, but not all seeds show grokking withying the first 100 checkpoints, NB!
    random_seed: int = 0
    device: str = DEVICE
    weight_decay: float = 0.0002


class MLP(nn.Module):
    def __init__(self, params):
        super().__init__()
        self.embedding = nn.Embedding(params.p, params.embed_dim)
        self.linear1r = nn.Linear(params.embed_dim, params.hidden_size, bias=True)
        self.linear2r = nn.Linear(params.hidden_size, params.hidden_size, bias=True)
        self.linear3r = nn.Linear(params.hidden_size, params.hidden_size, bias=True)
        self.linear1l = nn.Linear(params.embed_dim, params.hidden_size, bias=True)
        self.linear2l = nn.Linear(params.hidden_size, params.hidden_size, bias=True)
        self.linear3l = nn.Linear(params.hidden_size, params.hidden_size, bias=True)
        self.linear2 = nn.Linear(params.hidden_size, params.p, bias=False)
        self.act = nn.GELU()
        self.vocab_size = params.p

    def forward(self, x):
        x1 = self.embedding(x[..., 0])
        x2 = self.embedding(x[..., 1])
        x1 = self.linear1l(x1)
        x1 = self.linear2l(x1)
        x1 = self.linear3l(x1)
        x2 = self.linear1r(x2)
        x2 = self.linear2r(x2)
        x2 = self.linear3r(x2)
        x = x1 + x2
        x = self.act(x)
        x = self.linear2(x)
        return x


def test(model, dataset, device):
    n_correct = 0
    total_loss = 0
    model.eval()
    loss_fn = nn.CrossEntropyLoss()
    with torch.no_grad():
        for x, y in dataset:
            x, y = x.to(device), y.to(device)
            out = model(x)
            loss = loss_fn(out, y)
            total_loss += loss.item()
            pred = torch.argmax(out)
            if pred == y:
                n_correct += 1
    return n_correct / len(dataset), total_loss / len(dataset)


def train(train_dataset, test_dataset, params, verbose=True):
    all_models = []
    model = MLP(params).to(params.device)
    optimizer = torch.optim.Adam(
        model.parameters(), weight_decay=params.weight_decay, lr=params.lr
    )
    loss_fn = torch.nn.CrossEntropyLoss()

    train_loader = DataLoader(train_dataset, batch_size=params.batch_size, shuffle=True)

    print_every = params.n_batches // params.print_times
    checkpoint_every = None
    if params.n_save_model_checkpoints > 0:
        checkpoint_every = params.n_batches // params.n_save_model_checkpoints

    loss_data = []
    if verbose:
        pbar = tqdm(total=params.n_batches, desc="Training")
    for i in range(params.n_batches):
        # Sample random batch of data
        batch = next(iter(train_loader))
        X, Y = batch
        X, Y = X.to(params.device), Y.to(params.device)
        # Gradient update
        optimizer.zero_grad()
        out = model(X)
        loss = loss_fn(out, Y)
        loss.backward()
        optimizer.step()

        if checkpoint_every and (i + 1) % checkpoint_every == 0:
            all_models += [deepcopy(model)]

        if (i + 1) % print_every == 0:
            val_acc, val_loss = test(model, test_dataset, params.device)
            train_acc, train_loss = test(model, train_dataset, params.device)
            loss_data.append(
                {
                    "batch": i + 1,
                    "train_loss": train_loss,
                    "train_acc": train_acc,
                    "val_loss": val_loss,
                    "val_acc": val_acc,
                }
            )
            if verbose:
                pbar.set_postfix(
                    {
                        "train_loss": f"{train_loss:.4f}",
                        "train_acc": f"{train_acc:.4f}",
                        "val_loss": f"{val_loss:.4f}",
                        "val_acc": f"{val_acc:.4f}",
                    }
                )
                pbar.update(print_every)
    if verbose:
        pbar.close()
    df = pd.DataFrame(loss_data)
    train_acc, train_loss = test(model, train_dataset, params.device)
    val_acc, val_loss = test(model, test_dataset, params.device)
    if verbose:
        print(f"Final Train Acc: {val_acc:.4f} | Final Train Loss: {val_loss:.4f}")
        print(f"Final Val Acc: {val_acc:.4f} | Final Val Loss: {val_loss:.4f}")
    return all_models, df


def deterministic_shuffle(lst, seed):
    random.seed(seed)
    random.shuffle(lst)
    return lst


def get_all_pairs(p):
    pairs = []
    for i in range(p):
        for j in range(p):
            pairs.append((i, j))
    return set(pairs)


def make_dataset(p):
    data = []
    pairs = get_all_pairs(p)
    for a, b in pairs:
        data.append((torch.tensor([a, b]), torch.tensor((a + b) % p)))
    return data


def train_test_split(dataset, train_split_proportion, seed):
    l = len(dataset)
    train_len = int(train_split_proportion * l)
    idx = list(range(l))
    idx = deterministic_shuffle(idx, seed)
    train_idx = idx[:train_len]
    test_idx = idx[train_len:]
    return [dataset[i] for i in train_idx], [dataset[i] for i in test_idx]

# %%
# Initialize parameters and train the model
params = ExperimentParams()
torch.manual_seed(params.random_seed)

dataset = make_dataset(params.p)
train_data, test_data = train_test_split(dataset, params.train_frac, params.random_seed)

all_checkpointed_models, df = train(
    train_dataset=train_data, test_dataset=test_data, params=params
)
# Out:
# Training: 100%|██████████| 50000/50000 [04:41<00:00, 177.67it/s, train_loss=0.0036, train_acc=1.0000, val_loss=0.0151, val_acc=1.0000]
# Final Train Acc: 1.0000 | Final Train Loss: 0.0151
# Final Val Acc: 1.0000 | Final Val Loss: 0.0151

# %%
# Get model parameter count
model = MLP(params).to(params.device)
print(summary(model))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MLP                                      --
# ├─Embedding: 1-1                         636
# ├─Linear: 1-2                            624
# ├─Linear: 1-3                            2,352
# ├─Linear: 1-4                            2,352
# ├─Linear: 1-5                            624
# ├─Linear: 1-6                            2,352
# ├─Linear: 1-7                            2,352
# ├─Linear: 1-8                            2,544
# ├─GELU: 1-9                              --
# =================================================================
# Total params: 13,836
# Trainable params: 13,836
# Non-trainable params: 0
# =================================================================

# %%
plt.plot(df["val_acc"], label="test")
plt.plot(df["train_acc"], label="train")
plt.legend()
plt.ylabel("Correct answer %")
plt.xlabel("Checkpoint")
plt.title(f"Train & test correct answer % for modular addition with p={params.p}")
# Out:
# Text(0.5, 1.0, 'Train & test correct answer % for modular addition with p=53')

# %%
plt.plot(df["val_loss"], label="test")
plt.plot(df["train_loss"], label="train")
plt.legend()
plt.ylabel("Loss")
plt.xlabel("Checkpoint")
plt.title(f"Train & test loss for modular addition with p={params.p}")
# Out:
# Text(0.5, 1.0, 'Train & test loss for modular addition with p=53')

# %% [markdown]
# ## LLC estimation hyperparameter tuning

# %% [markdown]
# In order to get LLC estimates for this grokking model over training, we first need to choose hyperparameters. Let's run a quick sweep over a wide range of epsilon and n\*beta, and look for a range of values within this which shows little change in LLC change in LLC values when we change epsilon and nbeta. We can use `devinterp.vis_utils.EpsilonBetaAnalyzer` for this.

# %%
import typing
from typing import Type

import numpy as np


def estimate_llc_given_model(
    model: torch.nn.Module,
    loader: torch.utils.data.DataLoader,
    evaluate: typing.Callable,
    epsilon: float,
    beta: float,
    sampling_method: Type[torch.optim.Optimizer] = SGLD,
    localization: float = 5.0,
    num_chains: int = 2,
    num_draws: int = 500,
    num_burnin_steps: int = 0,
    num_steps_bw_draws: int = 1,
    device: torch.device = DEVICE,
    online: bool = True,
    verbose: bool = False,
):
    sweep_stats = estimate_learning_coeff_with_summary(
        model,
        loader=loader,
        evaluate=evaluate,
        sampling_method=sampling_method,
        optimizer_kwargs=dict(lr=epsilon, localization=localization, nbeta=beta),
        num_chains=num_chains,  # How many independent chains to run
        num_draws=num_draws,  # How many samples to draw per chain
        num_burnin_steps=num_burnin_steps,  # How many samples to discard at the beginning of each chain
        num_steps_bw_draws=num_steps_bw_draws,  # How many steps to take between each sample
        device=device,
        online=online,
        verbose=verbose,
    )

    sweep_stats["llc/trace"] = np.array(sweep_stats["llc/trace"])
    return sweep_stats

# %%
from devinterp.vis_utils import EpsilonBetaAnalyzer

loader = DataLoader(train_data, shuffle=True, batch_size=params.batch_size)
analyzer = EpsilonBetaAnalyzer()
analyzer.configure_sweep(
    llc_estimator=estimate_llc_given_model,
    llc_estimator_kwargs=dict(
        model=all_checkpointed_models[-1],
        evaluate=evaluate_ce,
        device=DEVICE,
        loader=loader,
    ),
    min_epsilon=3e-5,
    max_epsilon=3e-1,
    epsilon_samples=5,
    min_beta=None,
    max_beta=None,
    beta_samples=5,
    dataloader=loader,
)
analyzer.sweep()
# Out:
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:99: UserWarning: Epsilon values greater than 1e-2 typically lead to instability in the sampling process. Consider reducing epsilon to between 1e-6 and 1e-2.
#   warnings.warn(
#   0%|          | 0/25 [00:00<?, ?it/s]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/slt/sampler.py:117: UserWarning: Using passed in nbeta. Make sure callbacks are also initialized with the same nbeta.
#   warnings.warn(
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:240: UserWarning: You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#   warnings.warn(
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:244: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:285: UserWarning: If you're setting a nbeta or temperature in optimizer_kwargs, please also make sure to set it in the callbacks.
#   warnings.warn(
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:52: UserWarning: You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#   warnings.warn(
#  36%|███▌      | 9/25 [00:35<01:02,  3.89s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.00030000000000000014, beta=26380.709319112477. Skipping. Warning: NaN detected in loss at chain 0, draw 7
#   warnings.warn(
#  52%|█████▏    | 13/25 [00:47<00:42,  3.50s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.003000000000000001, beta=1483.4963037971102. Skipping. Warning: NaN detected in loss at chain 0, draw 6
#   warnings.warn(
#  56%|█████▌    | 14/25 [00:47<00:28,  2.55s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.003000000000000001, beta=26380.709319112477. Skipping. Warning: NaN detected in loss at chain 0, draw 4
#   warnings.warn(
#  68%|██████▊   | 17/25 [00:55<00:22,  2.87s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.03000000000000001, beta=83.42312773922517. Skipping. Warning: NaN detected in loss at chain 0, draw 6
#   warnings.warn(
#  72%|███████▏  | 18/25 [00:56<00:14,  2.12s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.03000000000000001, beta=1483.4963037971102. Skipping. Warning: NaN detected in loss at chain 0, draw 4
#   warnings.warn(
#  76%|███████▌  | 19/25 [00:56<00:09,  1.64s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.03000000000000001, beta=26380.709319112477. Skipping. Warning: NaN detected in loss at chain 0, draw 3
#   warnings.warn(
#  84%|████████▍ | 21/25 [01:00<00:08,  2.05s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.29999999999999993, beta=4.6912272204399645. Skipping. Warning: NaN detected in loss at chain 0, draw 5
#   warnings.warn(
#  88%|████████▊ | 22/25 [01:01<00:04,  1.55s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.29999999999999993, beta=83.42312773922517. Skipping. Warning: NaN detected in loss at chain 0, draw 3
#   warnings.warn(
#  92%|█████████▏| 23/25 [01:01<00:02,  1.25s/it]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.29999999999999993, beta=1483.4963037971102. Skipping. Warning: NaN detected in loss at chain 0, draw 3
#   warnings.warn(
#  96%|█████████▌| 24/25 [01:02<00:00,  1.01it/s]/home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/vis_utils.py:211: UserWarning: Error encountered for epsilon=0.29999999999999993, beta=26380.709319112477. Skipping. Warning: NaN detected in loss at chain 0, draw 3
#   warnings.warn(
# 100%|██████████| 25/25 [01:02<00:00,  2.50s/it]

# %%
analyzer.plot()

# %%
analyzer.plot(div_out_beta=True)

# %% [markdown]
# From this, we can see that the effective sampled loss for low-ish nbetas (<100) shows very little dependence on the exact choice of nbeta. So let's a point in this flat region (~1), and a high-but-still-in-the-flat-region epsilon (0.03), so we don't need to run many draws, but still have little dependence of our samples on epsilon.
#
# Let's check that the loss chain for these hyperparams looks decent, and then run LLC estimation on all trained checkpoints if it does.

# %%
lr = 3e-3
gamma = 5
nbeta = 2.0
num_draws = 150
num_chains = 2

# %%
learning_coeff_stats = estimate_learning_coeff_with_summary(
    all_checkpointed_models[-1],
    loader=DataLoader(train_data, batch_size=params.batch_size, shuffle=True),
    evaluate=evaluate_ce,
    sampling_method=SGLD,
    optimizer_kwargs=dict(lr=0.03, nbeta=2.0, localization=5.0),
    num_chains=3,
    num_draws=1500,
    device=DEVICE,
    online=True,
)
trace = learning_coeff_stats["loss/trace"]
# Out:
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/slt/sampler.py:117: UserWarning:
#
# Using passed in nbeta. Make sure callbacks are also initialized with the same nbeta.
#
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:240: UserWarning:
#
# You are taking more draws than burn-in steps, your LLC estimates will likely be underestimates. Please check LLC chain convergence.
#
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:244: UserWarning:
#
# You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:285: UserWarning:
#
# If you're setting a nbeta or temperature in optimizer_kwargs, please also make sure to set it in the callbacks.
#
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/backends/default/slt/sampler.py:52: UserWarning:
#
# You are taking more sample batches than there are dataloader batches available, this removes some randomness from sampling but is probably fine. (All sample batches beyond the number dataloader batches are cycled from the start, f.e. 9 samples from [A, B, C] would be [B, A, C, B, A, C, B, A, C].)
#
# Chain 0: 100%|██████████| 1500/1500 [00:05<00:00, 291.63it/s]
# Chain 1: 100%|██████████| 1500/1500 [00:05<00:00, 285.20it/s]
# Chain 2: 100%|██████████| 1500/1500 [00:05<00:00, 284.13it/s]

# %%
from devinterp.utils import plot_trace

plot_trace(
    trace,
    "Loss",
    x_axis="Step",
    title=f"Loss Trace, avg LLC = {sum(learning_coeff_stats['llc/means']) / len(learning_coeff_stats['llc/means']):.2f}",
    plot_mean=False,
    plot_std=False,
    fig_size=(12, 9),
    true_lc=None,
)

# %% [markdown]
# This looks good! The loss flattens out nicely, and well within the num_draws we chose. Looks like we can get away with using 150 draws, as the loss trace has well flattened out by then.

# %%
llcs = [
    estimate_learning_coeff_with_summary(
        model_checkpoint,
        loader=DataLoader(train_data, batch_size=params.batch_size, shuffle=True),
        evaluate=evaluate_ce,
        sampling_method=SGLD,
        optimizer_kwargs=dict(lr=lr, nbeta=nbeta, localization=gamma),
        num_chains=1,
        num_draws=num_draws,
        device=DEVICE,
        online=False,
    )
    for model_checkpoint in all_checkpointed_models
]
# Out:
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 285.40it/s]
# /home/wisp/anaconda3/envs/llc/lib/python3.10/site-packages/devinterp/slt/llc.py:109: UserWarning:
#
# std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1857.)
#
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 262.81it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 285.50it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 278.31it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 275.48it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 271.98it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 265.05it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 237.08it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 281.22it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 270.48it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 265.15it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 298.99it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 278.53it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 254.28it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 289.70it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 285.26it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 272.04it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 278.04it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 289.70it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 308.03it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 297.67it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 265.46it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 283.54it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 308.47it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 275.56it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 274.06it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 283.08it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 311.91it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 299.57it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 302.76it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 253.67it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 297.57it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 271.86it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 263.52it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 255.12it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 285.50it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 262.05it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 269.57it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 253.91it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 308.75it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 299.19it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 276.60it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 212.59it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 291.17it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 279.08it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 290.12it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 297.15it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 319.57it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 334.08it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 293.92it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 266.00it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 292.78it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 247.30it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 311.05it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 268.59it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 280.59it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 294.42it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 284.88it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 305.55it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 276.81it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 294.56it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 271.97it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 247.96it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 299.35it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 281.35it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 292.90it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 305.29it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 286.84it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 239.91it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 283.40it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 263.98it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 260.32it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 282.28it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 289.74it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 278.53it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 303.45it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 286.96it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 279.78it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 285.58it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 270.76it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 280.05it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 273.06it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 308.40it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 289.52it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 253.19it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 317.60it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 306.09it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 273.09it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 276.74it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 235.57it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 235.67it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 254.61it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 229.75it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 273.36it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 258.70it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 236.31it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 223.66it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 250.61it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 271.48it/s]
# Chain 0: 100%|██████████| 150/150 [00:00<00:00, 274.07it/s]

# %%
fig, ax1 = plt.subplots()
plt.title(
    f"Lambdahat vs loss for modular addition, 13836 params, 3 layers"
)
ax2 = ax1.twinx()
ax1.plot(df["val_loss"], label="test loss")
ax1.plot(df["train_loss"], label="train loss")
ax2.plot([llc["llc/mean"] for llc in llcs], color="g", label="Lambdahat")
ax1.set_xlabel("Checkpoint no.")
fig.legend(loc="center right")
