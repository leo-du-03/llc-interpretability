# %%
import torch
from torch.nn import functional as F

from devinterp.optim import SGLD
from devinterp.slt.sampler import estimate_learning_coeff_with_summary
from devinterp.utils import plot_trace, default_nbeta

from palindrome import check_palindrome
from tracr.haiku_to_pytorch import haiku_to_pytorch, apply
from trainedmodels import *

from dataloaders import makePalindromeDataLoader

# %%
loader = makePalindromeDataLoader()
assembled_model = check_palindrome()

# %%
model = train_model(loader, assembled_model, 5)
# Out:
# STARTING
# INFERRED HYPERPARAMETERS
# 4 1 2 2550 102 102
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x30a7c6a20>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1635b0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x30a7c69d0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163510>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163bf0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163c40>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163c90>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163d30>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163ce0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163d80>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163dd0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163e20>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163e70>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163ec0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163f10>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163f60>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f163fb0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148040>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148090>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1480e0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148130>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148180>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1481d0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148220>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148270>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1482c0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148310>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148360>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1483b0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148400>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148450>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1484a0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1484f0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148540>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148590>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1485e0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148630>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148680>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1486d0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148720>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148770>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1487c0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148810>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148860>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1488b0>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148900>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f148950>
# <class 'torch.nn.parameter.Parameter'> <built-in method size of Parameter object at 0x31f1489a0>
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/my/lbcwm42j2djgz4gg6dvrvs8h0000gn/T/ipykernel_884/688565009.py", line 1, in <module>
#     model = train_model(loader, assembled_model, 5)
#   File "/Users/aybarskocoglu/llc-interpretability/trainedmodels.py", line 117, in train_model
#     optimizer = optim.Adam(model.parameters(), lr=0.0001, betas=(0.9,0.98), eps=1e-9)
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/optim/adam.py", line 101, in __init__
#     super().__init__(params, defaults)
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/optim/optimizer.py", line 401, in __init__
#     self.add_param_group(cast(dict, param_group))
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_compile.py", line 46, in inner
#     import torch._dynamo
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/__init__.py", line 13, in <module>
#     from . import (
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/aot_compile.py", line 15, in <module>
#     from . import convert_frame
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py", line 57, in <module>
#     from torch._dynamo.symbolic_convert import TensorifyState
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/symbolic_convert.py", line 59, in <module>
#     from . import (
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/trace_rules.py", line 58, in <module>
#     from .variables import (
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/__init__.py", line 19, in <module>
#     from .base import VariableTracker
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/base.py", line 650, in <module>
#     from . import builder
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/builder.py", line 94, in <module>
#     from ..side_effects import SideEffects
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/side_effects.py", line 34, in <module>
#     from torch._dynamo.variables.misc import AutogradFunctionContextVariable
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/misc.py", line 61, in <module>
#     from .functions import NestedUserFunctionVariable, UserFunctionVariable
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_dynamo/variables/functions.py", line 88, in <module>
#     from torch.distributed.fsdp._fully_shard import _fsdp_param_group
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/fsdp/__init__.py", line 1, in <module>
#     from ._flat_param import FlatParameter as FlatParameter
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/fsdp/_flat_param.py", line 33, in <module>
#     from ._fsdp_extensions import (
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/fsdp/_fsdp_extensions.py", line 8, in <module>
#     from torch.distributed.fsdp._shard_utils import (
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/fsdp/_shard_utils.py", line 18, in <module>
#     from torch.distributed.tensor import DeviceMesh, DTensor, Replicate, Shard as DShard
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/tensor/__init__.py", line 4, in <module>
#     import torch.distributed.tensor._ops  # force import all built-in dtensor ops
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/tensor/_ops/__init__.py", line 2, in <module>
#     from ._conv_ops import *  # noqa: F403
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/tensor/_ops/_conv_ops.py", line 5, in <module>
#     from torch.distributed.tensor._dtensor_spec import DTensorSpec, TensorMeta
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/tensor/_dtensor_spec.py", line 6, in <module>
#     from torch.distributed.tensor.placement_types import (
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/tensor/placement_types.py", line 10, in <module>
#     from torch.distributed.tensor._collective_utils import (
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/distributed/tensor/_collective_utils.py", line 29, in <module>
#     def _shard_dim_alltoall_meta(input, gather_dim, shard_dim, group_name):
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/library.py", line 1063, in register
#     use_lib._register_fake(
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/library.py", line 190, in _register_fake
#     source = torch._library.utils.get_source(_stacklevel + 1)
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/torch/_library/utils.py", line 44, in get_source
#     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py", line 1629, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py", line 952, in findsource
#     module = getmodule(object, file)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py", line 869, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/haiku/_src/no_flax.py", line 26, in __getattr__
#     raise ImportError(
# ImportError: `haiku.experimental.flax.__file__` features require `flax` to be installed.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2170, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1457, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1348, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1195, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1085, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1153, in get_records
#     mod = inspect.getmodule(cf.tb_frame)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py", line 861, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py", line 844, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py", line 829, in getsourcefile
#     module = getmodule(object, filename)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py", line 869, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/aybarskocoglu/llc-interpretability/.venv/lib/python3.10/site-packages/haiku/_src/no_flax.py", line 26, in __getattr__
#     raise ImportError(
# ImportError: `haiku.experimental.flax.__file__` features require `flax` to be installed.
